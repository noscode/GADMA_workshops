# %% [markdown]
# # Model Comparison and Confidence Intervals Tutorial
#
# ## Outline
# 1. Block-Bootstrap
# 2. Model Comparison
# 3. Evaluate Confidence Intervals

# %% [markdown]
# -------
#
# ## 1. Block-Bootstrap
#
# Bootrap is a procedure to obtain data with similar characteristics, but different to the original data.
#
# **Bootstrap** - random sampling with replacement.
# <img src="pictures/bootstrap_illustration.png" width="900" align="left"/>

# %% [markdown]
# **Block-bootstrap** is a bootstrap performed over regions of linkage (e.g. genes). Usually 100 bootstraped data is generated.
#
# We will use a custom script that takes recombination rate as input and performs bootstrap over the regions of 0.5 Morgans length. BE CAREFULL, THIS PROCESS IS VERY TIME-CONSUMING!

# %%
# %%bash
# python scripts/perform_block_bootstrap.py
# Out:
# Usage: scripts/perform_block_bootstrap.py <original_VCF> <popmap> <rec_rate> <output_dir> <n_boots> <easySFS_location> <easySFS_arguments>

# %%
# %%bash
# # mkdir data
# # mkdir data/boots
# # python scripts/perform_block_bootstrap.py ../2_GADMA_tutorial/data/clouded_leopard_data.vcf ../2_GADMA_tutorial/data/popmap.txt 1e-6 data/boots 100 ../1_easySFS_tutorial/easySFS/easySFS.py "-a --unfolded --proj 14"

# %% [markdown]
# We have already run this script for you and you can find `.sfs` files in `data/boots` directory

# %%
# %%bash
# ls ../2_GADMA_tutorial/data/boots
# Out:
# 100.sfs
# 10.sfs
# 11.sfs
# 12.sfs
# 13.sfs
# 14.sfs
# 15.sfs
# 16.sfs
# 17.sfs
# 18.sfs
# 19.sfs
# 1.sfs
# 20.sfs
# 21.sfs
# 22.sfs
# 23.sfs
# 24.sfs
# 25.sfs
# 26.sfs
# 27.sfs
# 28.sfs
# 29.sfs
# 2.sfs
# 30.sfs
# 31.sfs
# 32.sfs
# 33.sfs
# 34.sfs
# 35.sfs
# 36.sfs
# 37.sfs
# 38.sfs
# 39.sfs
# 3.sfs
# 40.sfs
# 41.sfs
# 42.sfs
# 43.sfs
# 44.sfs
# 45.sfs
# 46.sfs
# 47.sfs
# 48.sfs
# 49.sfs
# 4.sfs
# 50.sfs
# 51.sfs
# 52.sfs
# 53.sfs
# 54.sfs
# 55.sfs
# 56.sfs
# 57.sfs
# 58.sfs
# 59.sfs
# 5.sfs
# 60.sfs
# 61.sfs
# 62.sfs
# 63.sfs
# 64.sfs
# 65.sfs
# 66.sfs
# 67.sfs
# 68.sfs
# 69.sfs
# 6.sfs
# 70.sfs
# 71.sfs
# 72.sfs
# 73.sfs
# 74.sfs
# 75.sfs
# 76.sfs
# 77.sfs
# 78.sfs
# 79.sfs
# 7.sfs
# 80.sfs
# 81.sfs
# 82.sfs
# 83.sfs
# 84.sfs
# 85.sfs
# 86.sfs
# 87.sfs
# 88.sfs
# 89.sfs
# 8.sfs
# 90.sfs
# 91.sfs
# 92.sfs
# 93.sfs
# 94.sfs
# 95.sfs
# 96.sfs
# 97.sfs
# 98.sfs
# 99.sfs
# 9.sfs

# %% [markdown]
# We can draw several of those SFS:

# %%
from scripts.draw_sfs import draw_1d_sfs
draw_1d_sfs("../2_GADMA_tutorial/data/boots/1.sfs")

# %%
from scripts.draw_sfs import draw_1d_sfs
draw_1d_sfs("../2_GADMA_tutorial/data/boots/2.sfs")

# %% [markdown]
# ## 1. Model comparison
#
# We can compare models with different numbers of paramters (e.g. one-epoch history, two-epoch history and etc.) using AIC or CLAIC. More information is available [here](https://gadma.readthedocs.io/en/latest/user_manual/input_data/input_data.html#unlinked-snps-aic-and-claic).
# - AIC could be used if our SNP's are **unlinked**, independent. It is usually a case of RAD-like data, remember `easySFS` offered us to choose one SNP per RAD locus? That is exactly the way to get set of unlinked SNP's. Another option is to use LD pruning. Both solutions lead to data lost.
# - CLAIC [\[Coffman 2016\]](https://doi.org/10.1093/molbev/msv255) is applied when our SNP's are linked (general case). In order to evaluate CLAIC we should provide additional **block-bootstraped** data. Bootstrap should be performed over the regions of linkage (usually genes). A little more about bootstrap will be further. Here we just got some directory with bootstraped data.

# %%
# %%bash
# cat gadma_params_files/params_model_comparison
# Out:
# Input data: ../2_GADMA_tutorial/outputs/easySFS_output/dadi/NN-10.sfs
# Output directory: outputs/gadma_outputs/gadma_model_comparison
#
# # We want compare final demographic histories with different
# # numbers of epochs using CLAIC
# Linked SNP's : True
# Directory with bootstrap: ../2_GADMA_tutorial/data/boots
#
# Mutation rate: 1.554e-8
# Sequence length: 118000000
# Time for generation: 7
#
# Engine: moments
#
# Initial structure: 1
# Final structure: 3
#
# Number of repeats: 8
# Number of processes: 4

# %%
# %%bash
# #mkdir outputs
# #mkdir outputs/gadma_outputs
# rm -rf outputs/gadma_outputs/gadma_model_comparison
# gadma -p gadma_params_files/params_model_comparison
# Out:
# Data reading
# Number of populations: 1
# Projections: [10]
# Population labels: ['NN']
# Outgroup: True
# --Successful data reading (0.00 s)--
#
# --Successful arguments parsing--
#
# Bootstrap data reading
# Number of files found: 100
# --Successful bootstrap data reading (0.01 s)--
# UserWarning: Code for momentsLD will not be generated as data was not preprocessed for it (run gadma-precompute_ld_data script on the VCF file first) (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/gadma/cli/settings_storage.py:1510)
# Parameters of launch are saved in output directory: /home/enoskova/Workspace/GADMA_workshops/2025-12-Demographic_Inference_Worshop/tutorials/3_Model_Selection_tutorial/outputs/gadma_outputs/gadma_model_comparison/params_file
# All output is saved in output directory: /home/enoskova/Workspace/GADMA_workshops/2025-12-Demographic_Inference_Worshop/tutorials/3_Model_Selection_tutorial/outputs/gadma_outputs/gadma_model_comparison/GADMA.log
#
# --Start pipeline--
# Run launch number 1
# Run launch number 2
# Run launch number 3
# Run launch number 4
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# [000:01:00]
# All best by log-likelihood models
# Number	log-likelihood	Model	Units
# Run 1	-315.05	 [Nanc = 341438] [ [ 106114.559(t1), [36571.15(nu11)], [Sud(dyn11)] ] ]	(theta =  2504413.01)	physical, time in years
# Run 2	-321.16	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	(theta =  2503439.69)	physical, time in years
# Run 3	-335.28	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	(theta =  2507021.88)	physical, time in years
# Run 4	-468.64	 [Nanc = 343654] [ [ 142695.89(t1), [180289.568(nu11)], [Lin(dyn11)] ],	[ 287333.695(t2), [30203.516(nu21)], [Lin(dyn21)] ] ]	m	(theta =  2520667.88)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# All best by CLAIC score models
# Number	log-likelihood	CLAIC score	Model	Units
# Run 2	-321.38	645.93 (eps=1.0e-05)	 [Nanc = 341518] [ [ 234329.089(t1), [25437.211(nu11)], [Exp(dyn11)] ] ]	(theta =  2504994.55)	physical, time in years
# Run 3	-335.39	671.29 (eps=1.0e-05)	 [Nanc = 341800] [ [ 395457.554(t1), [15184.81(nu11)], [Lin(dyn11)] ] ]	(theta =  2507064.98)	physical, time in years
# Run 4	-519.06	1746.84 (eps=1.0e-05)	 [Nanc = 344711] [ [ 576434.343(t1), [30296.384(nu11)], [Lin(dyn11)] ] ]	(theta =  2528418.28)	physical, time in years
# Run 1	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 3	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 2	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 4	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# Finish genetic algorithm number 3
# Run launch number 5
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# Finish genetic algorithm number 2
# Run launch number 6
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# Finish genetic algorithm number 4
# Run launch number 7
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# Finish genetic algorithm number 1
# Run launch number 8
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# [000:02:00]
# All best by log-likelihood models
# Number	log-likelihood	Model	Units
# Run 1	-314.11	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 6	-317.51	 [Nanc = 340803] [ [ 88027.152(t1), [31302.542(nu11)], [Sud(dyn11)] ] ]	(theta =  2499755.36)	physical, time in years
# Run 2	-321.16	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.28	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 7	-365.85	 [Nanc = 343182] [ [ 474606.347(t1), [21727.559(nu11)], [Lin(dyn11)] ] ]	(theta =  2517202.22)	physical, time in years
# Run 4	-409.46	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
# Run 5	-633.38	 [Nanc = 337637] [ [ 236.232(t1), [337637.179(nu11)], [Sud(dyn11)] ],	[ 50753.443(t2), [4585.433(nu21)], [Exp(dyn21)] ] ]	c	(theta =  2476528.19)	physical, time in years
# Run 8	-678.66	 [Nanc = 346738] [ [ 421863.534(t1), [14957.891(nu11)], [Lin(dyn11)] ] ]	mm	(theta =  2543282.54)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# All best by CLAIC score models
# Number	log-likelihood	CLAIC score	Model	Units
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	(theta =  2502534.75)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2502534.75)	physical, time in years
# Run 1	-314.11	643.08 (eps=1.0e-05)	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 2	-321.38	645.93 (eps=1.0e-05)	 [Nanc = 341518] [ [ 234329.089(t1), [25437.211(nu11)], [Exp(dyn11)] ] ]	(theta =  2504994.55)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	(theta =  2503439.69)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.39	671.29 (eps=1.0e-05)	 [Nanc = 341800] [ [ 395457.554(t1), [15184.81(nu11)], [Lin(dyn11)] ] ]	(theta =  2507064.98)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	(theta =  2507021.88)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	(theta =  2515104.25)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
# Run 5	-633.38	1267.15 (eps=1.0e-05)	 [Nanc = 337637] [ [ 50753.443(t1), [4585.433(nu11)], [Exp(dyn11)] ] ]	(theta =  2476528.19)	physical, time in years
# Run 4	-519.06	1746.84 (eps=1.0e-05)	 [Nanc = 344711] [ [ 576434.343(t1), [30296.384(nu11)], [Lin(dyn11)] ] ]	(theta =  2528418.28)	physical, time in years
# Run 1	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 3	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 2	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 4	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 5	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 6	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 7	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 8	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# RuntimeWarning: Mean of empty slice. (/home/enoskova/miniconda3/envs/gadma_workshop_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504)
# Finish genetic algorithm number 6
# Finish genetic algorithm number 7
#
# [000:03:00]
# All best by log-likelihood models
# Number	log-likelihood	Model	Units
# Run 1	-314.11	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 6	-317.51	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2499811.71)	physical, time in years
# Run 2	-321.16	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.28	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 8	-336.07	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	(theta =  2506385.28)	physical, time in years
# Run 5	-350.31	 [Nanc = 333832] [ [ 64039.571(t1), [796844.16(nu11)], [Exp(dyn11)] ],	[ 1445968.474(t2), [25166.741(nu21)], [Lin(dyn21)] ] ]	m	(theta =  2448621.45)	physical, time in years
# Run 7	-365.85	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2517202.39)	physical, time in years
# Run 4	-409.46	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# All best by CLAIC score models
# Number	log-likelihood	CLAIC score	Model	Units
# Run 6	-317.51	638.14 (eps=1.0e-05)	 [Nanc = 340803] [ [ 88027.152(t1), [31302.542(nu11)], [Sud(dyn11)] ] ]	(theta =  2499755.36)	physical, time in years
# Run 6	-317.51	638.21 (eps=1.0e-05)	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	(theta =  2499811.71)	physical, time in years
# Run 6	-317.51	638.21 (eps=1.0e-05)	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2499811.71)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	(theta =  2502534.75)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2502534.75)	physical, time in years
# Run 1	-314.11	643.08 (eps=1.0e-05)	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 2	-321.38	645.93 (eps=1.0e-05)	 [Nanc = 341518] [ [ 234329.089(t1), [25437.211(nu11)], [Exp(dyn11)] ] ]	(theta =  2504994.55)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	(theta =  2503439.69)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.39	671.29 (eps=1.0e-05)	 [Nanc = 341800] [ [ 395457.554(t1), [15184.81(nu11)], [Lin(dyn11)] ] ]	(theta =  2507064.98)	physical, time in years
# Run 8	-336.13	674.76 (eps=1.0e-05)	 [Nanc = 341761] [ [ 390506.558(t1), [14758.01(nu11)], [Lin(dyn11)] ] ]	(theta =  2506778.36)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	(theta =  2507021.88)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 7	-365.85	868.24 (eps=1.0e-05)	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	(theta =  2517202.39)	physical, time in years
# Run 7	-365.85	868.24 (eps=1.0e-05)	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2517202.39)	physical, time in years
# Run 7	-365.85	868.31 (eps=1.0e-05)	 [Nanc = 343182] [ [ 474606.339(t1), [21727.559(nu11)], [Lin(dyn11)] ] ]	(theta =  2517202.21)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	(theta =  2515104.25)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
# Run 5	-633.38	1267.15 (eps=1.0e-05)	 [Nanc = 337637] [ [ 50753.443(t1), [4585.433(nu11)], [Exp(dyn11)] ] ]	(theta =  2476528.19)	physical, time in years
# Run 4	-519.06	1746.84 (eps=1.0e-05)	 [Nanc = 344711] [ [ 576434.343(t1), [30296.384(nu11)], [Lin(dyn11)] ] ]	(theta =  2528418.28)	physical, time in years
# Run 1	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 3	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 2	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 4	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 5	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 6	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 7	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 8	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# Finish genetic algorithm number 8
#
# [000:04:00]
# All best by log-likelihood models
# Number	log-likelihood	Model	Units
# Run 1	-314.11	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 6	-317.51	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2499811.71)	physical, time in years
# Run 2	-321.16	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.28	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 8	-336.07	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2506385.28)	physical, time in years
# Run 5	-342.74	 [Nanc = 334855] [ [ 8.68e-05(t1), [800085.993(nu11)], [Exp(dyn11)] ],	[ 1450400.039(t2), [25243.871(nu21)], [Lin(dyn21)] ] ]	(theta =  2456125.92)	physical, time in years
# Run 7	-365.85	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2517202.39)	physical, time in years
# Run 4	-409.46	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# All best by CLAIC score models
# Number	log-likelihood	CLAIC score	Model	Units
# Run 6	-317.51	638.14 (eps=1.0e-05)	 [Nanc = 340803] [ [ 88027.152(t1), [31302.542(nu11)], [Sud(dyn11)] ] ]	(theta =  2499755.36)	physical, time in years
# Run 6	-317.51	638.21 (eps=1.0e-05)	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	(theta =  2499811.71)	physical, time in years
# Run 6	-317.51	638.21 (eps=1.0e-05)	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2499811.71)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	(theta =  2502534.75)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2502534.75)	physical, time in years
# Run 1	-314.11	643.08 (eps=1.0e-05)	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 2	-321.38	645.93 (eps=1.0e-05)	 [Nanc = 341518] [ [ 234329.089(t1), [25437.211(nu11)], [Exp(dyn11)] ] ]	(theta =  2504994.55)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	(theta =  2503439.69)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.39	671.29 (eps=1.0e-05)	 [Nanc = 341800] [ [ 395457.554(t1), [15184.81(nu11)], [Lin(dyn11)] ] ]	(theta =  2507064.98)	physical, time in years
# Run 8	-336.07	674.61 (eps=1.0e-05)	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	(theta =  2506385.28)	physical, time in years
# Run 8	-336.07	674.61 (eps=1.0e-05)	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2506385.28)	physical, time in years
# Run 8	-336.13	674.76 (eps=1.0e-05)	 [Nanc = 341761] [ [ 390506.558(t1), [14758.01(nu11)], [Lin(dyn11)] ] ]	(theta =  2506778.36)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	(theta =  2507021.88)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 7	-365.85	868.24 (eps=1.0e-05)	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	(theta =  2517202.39)	physical, time in years
# Run 7	-365.85	868.24 (eps=1.0e-05)	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2517202.39)	physical, time in years
# Run 7	-365.85	868.31 (eps=1.0e-05)	 [Nanc = 343182] [ [ 474606.339(t1), [21727.559(nu11)], [Lin(dyn11)] ] ]	(theta =  2517202.21)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	(theta =  2515104.25)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
# Run 5	-633.38	1267.15 (eps=1.0e-05)	 [Nanc = 337637] [ [ 50753.443(t1), [4585.433(nu11)], [Exp(dyn11)] ] ]	(theta =  2476528.19)	physical, time in years
# Run 4	-519.06	1746.84 (eps=1.0e-05)	 [Nanc = 344711] [ [ 576434.343(t1), [30296.384(nu11)], [Lin(dyn11)] ] ]	(theta =  2528418.28)	physical, time in years
# Run 1	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 3	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 2	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 4	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 5	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 6	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 7	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 8	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# Finish genetic algorithm number 5
#
# [000:04:15]
# All best by log-likelihood models
# Number	log-likelihood	Model	Units
# Run 1	-314.11	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 6	-317.51	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2499811.71)	physical, time in years
# Run 2	-321.16	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.28	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 8	-336.07	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2506385.28)	physical, time in years
# Run 5	-342.74	 [Nanc = 334855] [ [ 8.68e-05(t1), [800085.993(nu11)], [Exp(dyn11)] ],	[ 1450400.039(t2), [25243.871(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2456125.92)	physical, time in years
# Run 7	-365.85	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2517202.39)	physical, time in years
# Run 4	-409.46	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
# All best by CLAIC score models
# Number	log-likelihood	CLAIC score	Model	Units
# Run 6	-317.51	638.14 (eps=1.0e-05)	 [Nanc = 340803] [ [ 88027.152(t1), [31302.542(nu11)], [Sud(dyn11)] ] ]	(theta =  2499755.36)	physical, time in years
# Run 6	-317.51	638.21 (eps=1.0e-05)	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	(theta =  2499811.71)	physical, time in years
# Run 6	-317.51	638.21 (eps=1.0e-05)	 [Nanc = 340811] [ [ 5.213(t1), [18960.074(nu11)], [Sud(dyn11)] ],	[ 88029.136(t2), [31303.247(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2499811.71)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	(theta =  2502534.75)	physical, time in years
# Run 1	-314.12	643.03 (eps=1.0e-05)	 [Nanc = 341182] [ [ 51427.872(t1), [35701.43(nu11)], [Sud(dyn11)] ],	[ 51427.872(t2), [35701.43(nu21)], [Sud(dyn21)] ] ]	f	(theta =  2502534.75)	physical, time in years
# Run 1	-314.11	643.08 (eps=1.0e-05)	 [Nanc = 341182] [ [ 102855.809(t1), [35701.452(nu11)], [Sud(dyn11)] ] ]	(theta =  2502536.34)	physical, time in years
# Run 2	-321.38	645.93 (eps=1.0e-05)	 [Nanc = 341518] [ [ 234329.089(t1), [25437.211(nu11)], [Exp(dyn11)] ] ]	(theta =  2504994.55)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	(theta =  2503439.69)	physical, time in years
# Run 2	-321.16	659.44 (eps=1.0e-05)	 [Nanc = 341306] [ [ 3893172.485(t1), [341647.632(nu11)], [Sud(dyn11)] ],	[ 234184.81(t2), [25421.422(nu21)], [Exp(dyn21)] ] ]	f	(theta =  2503439.69)	physical, time in years
# Run 3	-335.39	671.29 (eps=1.0e-05)	 [Nanc = 341800] [ [ 395457.554(t1), [15184.81(nu11)], [Lin(dyn11)] ] ]	(theta =  2507064.98)	physical, time in years
# Run 8	-336.07	674.61 (eps=1.0e-05)	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	(theta =  2506385.28)	physical, time in years
# Run 8	-336.07	674.61 (eps=1.0e-05)	 [Nanc = 341707] [ [ 0.902(t1), [341707.758(nu11)], [Sud(dyn11)] ],	[ 390334.891(t2), [14770.461(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2506385.28)	physical, time in years
# Run 8	-336.13	674.76 (eps=1.0e-05)	 [Nanc = 341761] [ [ 390506.558(t1), [14758.01(nu11)], [Lin(dyn11)] ] ]	(theta =  2506778.36)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	(theta =  2507021.88)	physical, time in years
# Run 3	-335.28	686.83 (eps=1.0e-05)	 [Nanc = 341794] [ [ 197725.377(t1), [178421.793(nu11)], [Lin(dyn11)] ],	[ 197725.377(t2), [15199.741(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2507021.88)	physical, time in years
# Run 5	-342.74	802.63 (eps=1.0e-05)	 [Nanc = 334855] [ [ 8.68e-05(t1), [800085.993(nu11)], [Exp(dyn11)] ],	[ 1450400.039(t2), [25243.871(nu21)], [Lin(dyn21)] ] ]	(theta =  2456125.92)	physical, time in years
# Run 5	-342.74	802.63 (eps=1.0e-05)	 [Nanc = 334855] [ [ 8.68e-05(t1), [800085.993(nu11)], [Exp(dyn11)] ],	[ 1450400.039(t2), [25243.871(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2456125.92)	physical, time in years
# Run 7	-365.85	868.24 (eps=1.0e-05)	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	(theta =  2517202.39)	physical, time in years
# Run 7	-365.85	868.24 (eps=1.0e-05)	 [Nanc = 343182] [ [ 192.514(t1), [343182.444(nu11)], [Lin(dyn11)] ],	[ 474606.313(t2), [21727.547(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2517202.39)	physical, time in years
# Run 7	-365.85	868.31 (eps=1.0e-05)	 [Nanc = 343182] [ [ 474606.339(t1), [21727.559(nu11)], [Lin(dyn11)] ] ]	(theta =  2517202.21)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	(theta =  2515104.25)	physical, time in years
# Run 4	-409.46	1031.78 (eps=1.0e-05)	 [Nanc = 342896] [ [ 178890.22(t1), [159686.535(nu11)], [Lin(dyn11)] ],	[ 234987.848(t2), [26902.024(nu21)], [Lin(dyn21)] ] ]	f	(theta =  2515104.25)	physical, time in years
# Run 5	-633.38	1267.15 (eps=1.0e-05)	 [Nanc = 337637] [ [ 50753.443(t1), [4585.433(nu11)], [Exp(dyn11)] ] ]	(theta =  2476528.19)	physical, time in years
# Run 4	-519.06	1746.84 (eps=1.0e-05)	 [Nanc = 344711] [ [ 576434.343(t1), [30296.384(nu11)], [Lin(dyn11)] ] ]	(theta =  2528418.28)	physical, time in years
# Run 1	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 3	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 2	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 4	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 5	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 6	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 7	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
# Run 8	-183140.18	366280.36 (eps=1.0e-05)	 [Nanc = 262370] [  ]	(theta =  1924455.32)	physical, time in years
#
# You can find the picture and the Python code of the best model in the output directory.
#
#
# --Finish pipeline--
#
#
# If you use GADMA in your research please cite:
# [GADMA]
# Noskova et al., 2020: https://doi.org/10.1093/gigascience/giaa005
# Noskova et al., 2023: https://doi.org/10.1093/gigascience/giad059
# [Engine moments]
# Jouganous et al., 2017: https://doi.org/10.1534/genetics.117.200493
# [CLAIC evaluation]
# Coffman et al., 2016: https://doi.org/10.1093/molbev/msv255
#
# More information about citations: https://gadma.readthedocs.io/en/latest/citations.html
#
#
# Thank you for using GADMA!
#
# In case of any questions or problems, please contact: ekaterina.e.noskova@gmail.com

# %% [markdown]
# Final demographic history (`outputs/gadma_outputs/gadma_model_comparison/best_claic_model.png` file):
# <img src="outputs/gadma_outputs/gadma_model_comparison/best_claic_model.png" width="900" align="left"/>

# %% [markdown]
# ----
# ## 8. Evaluate Confidence Intervals (CI) for the Final Model
#
# For our final model we want to get confidence intervals for its parameters. We will also use block-boostraped data.

# %%
# %%bash
# # If you want to start from scratch remove the output directory
# rm -rf confidence_intervals
# gadma-run_ls_on_boot_data -b ../2_GADMA_tutorial/data/boots -d outputs/gadma_outputs/gadma_model_comparison/best_claic_model_moments_code.py\
#     -o confidence_intervals --opt log -e moments

# %%
# %%bash
# python scripts/translate_units.py confidence_intervals/result_table.csv 7.33488
# cat confidence_intervals/result_table_translated.csv
# Out:
# ,Nanc,t1,nu11
# 94.sfs,488493.2228330445,19001.87782574937,44867.68387585137
# 71.sfs,494666.3819146283,16729.122904702548,43573.18962956763
# 84.sfs,128519.06456496938,5270.2464974427185,11815.59471977523
# 72.sfs,461058.0268175107,17934.677261964203,42347.784633937634
# 88.sfs,434878.63752500934,15833.150074568472,39983.294679276696
# 93.sfs,253359.1943892878,9368.364147901484,23269.849766933326
# 52.sfs,320360.9561505183,10836.495916513999,27672.966915520774
# 33.sfs,271497.32222931925,7686.725928425766,19304.769425925137
# 67.sfs,109011.36989384869,6967.689875880247,14546.033803146394
# 40.sfs,703692.0043381342,25965.502386433338,64633.50753056109
# 4.sfs,287021.12868180167,11154.787392587574,26387.793043192745
# 64.sfs,208489.22662890522,6213.207871828259,17130.195821969282
# 89.sfs,526200.1271527321,19416.2368949705,48331.030722591444
# 53.sfs,606319.1325771745,22099.63717253847,55745.700791487405
# 98.sfs,360009.02810914925,13283.958352343225,33066.52070211921
# 87.sfs,430730.25498725724,15893.498000307753,39562.20478239519
# 95.sfs,267609.8788569717,10402.864107859932,24602.821163636112
# 42.sfs,261998.37411205308,10191.464001382328,24064.326128152472
# 97.sfs,415342.77853554324,15056.852433947923,38187.187465955634
# 47.sfs,398669.27677078807,13914.359030279793,36617.82734377593
# 43.sfs,235012.0523983143,8056.866765115069,21046.888300719223
# 50.sfs,420840.1308724547,14750.83016234735,37606.84031834295
# 78.sfs,81117.04717277638,2383.305716404886,5524.546787785758
# 81.sfs,415342.77853554324,15056.852433947923,38187.187465955634
# 37.sfs,332899.45504613215,12283.643328543854,30576.529649333483
# 41.sfs,826378.3689525313,30492.501518921756,75902.14497750795
# 35.sfs,101114.70044081366,2947.664881262862,6758.689926179832
# 15.sfs,334643.5783658117,12277.21329071598,30767.494685024903
# 30.sfs,294581.9856212307,9493.916812528849,25889.067194278006
# 49.sfs,354269.41625726986,13072.17265019306,32571.897889770953
# 7.sfs,75732.53965159287,3182.2833937305045,6962.408915915009
# 58.sfs,235012.0523983143,8056.866765115069,21046.888300719223
# 36.sfs,346454.2415776437,12783.800840444022,31821.525175726627
# 2.sfs,155368.44830457267,5732.933997201332,14284.7364215986
# 80.sfs,229359.91403103666,8091.535984325481,21087.846213496847
# 55.sfs,354269.41625726986,13072.17265019306,32571.897889770953
# 28.sfs,526200.1271527321,19416.2368949705,48331.030722591444
# 51.sfs,420840.1308724547,14750.83016234735,37606.84031834295
# 60.sfs,420840.1308724547,14750.83016234735,37606.84031834295
# 99.sfs,591563.843593182,20037.25934110244,51410.029227965526
# 10.sfs,531850.5162233172,19624.730369321882,48850.014116310325
# 82.sfs,545405.302755139,20124.88788128546,50095.00964273198
# 18.sfs,420840.1308724547,14750.83016234735,37606.84031834295
# 17.sfs,890679.6147835458,33130.29289778645,81807.67077945858
# 77.sfs,334643.5783658117,12277.21329071598,30767.494685024903
# 54.sfs,220002.27754465025,5653.15517729853,15684.855930055479
# 79.sfs,621776.918704123,22942.9210036618,57109.677116753555
# 62.sfs,314710.88918575074,10814.235041656042,27574.490781774657
# 83.sfs,346454.2415776437,12783.800840444022,31821.525175726627
# 96.sfs,404671.2699674281,10602.765259017022,28629.31742625827
# 22.sfs,415342.77853554324,15056.852433947923,38187.187465955634
# 91.sfs,512645.3406207858,18916.07938298168,47086.035196158366
# 1.sfs,223525.01580726285,7846.043771985614,20551.426155765097
# 14.sfs,698041.6152672176,25757.00891201464,64114.52413681174
# 12.sfs,469057.3668739489,18245.84326250258,43082.5171626433
# 26.sfs,262161.94632983336,9309.659433260957,24103.69495598436
# 20.sfs,398669.27677078807,13914.359030279793,36617.82734377593
# 68.sfs,281434.23007114866,10947.498564629119,25849.492841360538
# 34.sfs,168829.05572088214,6214.505297867286,15522.322983137972
# 65.sfs,777046.1888556466,27194.33570905695,69143.30159817844
# 75.sfs,512645.3406207858,18916.07938298168,47086.035196158366
# 45.sfs,545405.302755139,20124.88788128546,50095.00964273198
# 13.sfs,308670.23581307486,10584.776161157584,28351.690080595654
# 57.sfs,392662.56581603846,13635.14995041689,36066.203264185315
# 59.sfs,248508.70257194855,8636.416785904143,20586.6648155926
# 86.sfs,531850.5162233172,19624.730369321882,48850.014116310325
# 11.sfs,415342.77853554324,15056.852433947923,38187.187465955634
# 70.sfs,512645.3406207858,18916.07938298168,47086.035196158366
# 44.sfs,420840.1308724547,14750.83016234735,37606.84031834295
# 19.sfs,42986.53848255494,1586.1585191703277,3948.2767199240766
# 69.sfs,235012.0523983143,8056.866765115069,21046.888300719223
# 38.sfs,346454.2415776437,12783.800840444022,31821.525175726627
# 66.sfs,545405.302755139,20124.88788128546,50095.00964273198
# 8.sfs,75732.53965159287,3182.2833937305045,6962.408915915009
# 16.sfs,640982.0943065338,23651.57198997749,58873.656036894456
# 6.sfs,777046.1888556466,27194.33570905695,69143.30159817844
# 39.sfs,334643.5783658117,12277.21329071598,30767.494685024903
# 73.sfs,591563.843593182,20037.25934110244,51410.029227965526
# 25.sfs,261998.37411205308,10191.464001382328,24064.326128152472
# 100.sfs,654536.880838032,24151.7295018747,60118.65156328637
# 56.sfs,55753.13237544151,1806.8820332147588,4118.736682010007
# 61.sfs,354269.41625726986,13072.17265019306,32571.897889770953
# 24.sfs,450268.4701353582,16668.250219959784,41353.13999054577
# 92.sfs,320360.9561505183,10836.495916513999,27672.966915520774
# 21.sfs,96381.3557273843,4198.7029406881065,8860.608631718183
# 31.sfs,267609.8788569717,10402.864107859932,24602.821163636112
# 48.sfs,302708.9573824254,10326.823816644763,27832.030088238083
# 46.sfs,505920.2475159254,18019.872947142507,45426.44681077175
# 74.sfs,531850.5162233172,19624.730369321882,48850.014116310325
# 76.sfs,340803.85250673804,12575.30736602685,31302.541781978278
# 32.sfs,488493.2228330445,19001.87782574937,44867.68387585137
# 9.sfs,398669.27677078807,13914.359030279793,36617.82734377593
# 23.sfs,436380.6440581713,16101.991474726165,40081.18817614427
# 63.sfs,392662.56581603846,13635.14995041689,36066.203264185315
# 29.sfs,360009.02810914925,13283.958352343225,33066.52070211921
# 5.sfs,531850.5162233172,19624.730369321882,48850.014116310325
# 27.sfs,474775.6248252776,18468.277543856788,43607.7342548945
# 90.sfs,332899.45504613215,12283.643328543854,30576.529649333483
# 3.sfs,267609.8788569717,10402.864107859932,24602.821163636112
# 85.sfs,55753.13237544151,1806.8820332147588,4118.736682010007

# %% [markdown]
# The last argument (7.33488) is called theta0 and it is equal to $4*\mu*L$, where $\mu$ is mutation rate and $L$ is the sequence length from GADMA. For our cloded leopard data we have $\mu = 1.554 \times 10^{-8}$ and $L=118{,}000{,}000$.

# %%
# %%bash
# python scripts/translate_units.py
# Out:
# Usage: scripts/translate_units.py <input_file.csv> <theta0>

# %%
# %%bash
# gadma-get_confidence_intervals confidence_intervals/result_table_translated.csv
# Out:
# Nanc:	41920.76150	725629.55804	data does not look normal (reject H0) p-value=2.81e-01
# t1:	1320.55313	26470.58014	data does not look normal (reject H0) p-value=2.46e-01
# nu11:	3266.44730	66227.36371	data does not look normal (reject H0) p-value=3.21e-01

# %% [markdown]
# ### Another way to evaluate CI's
#
# There is a method from [\[Coffman 2016\]](https://doi.org/10.1093/molbev/msv255) that also allows to estimate confidence intervals for the parameters.
# - Estimates ancertancy using Godambe Information Matrix.
# - Requires bootstrap data.
# - Does NOT require the whole machinery we just used.
# - However, there is no universal script to use it.
# - Provides different confidence intervals.
#
# Example script for specific model and data could be found [here](https://github.com/pblischak/inbreeding-sfs/blob/master/data/cabbage/run_cabbage_godambe_3epoch_noF.py). You can use it for your model.
